# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv')

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
# answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '723   Pirates of the Caribbean: On Stranger Tides'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
tmp = data.sort_values(by=['budget'], ascending=False)
tmp[['original_title','budget']]
# Out:
#                                    original_title     budget
# 723   Pirates of the Caribbean: On Stranger Tides  380000000
# 1669     Pirates of the Caribbean: At World's End  300000000
# 14                        Avengers: Age of Ultron  280000000
# 1014                                  John Carter  260000000
# 380                                       Tangled  260000000
# ...                                           ...        ...
# 885               National Lampoonâ€™s Van Wilder    5000000
# 892                      My Big Fat Greek Wedding    5000000
# 1071                        Paranormal Activity 4    5000000
# 911                            Jackass: The Movie    5000000
# 1216                              Spring Breakers    5000000
#
# [1889 rows x 2 columns]

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '1157	Gods and Generals'

# %%
tmp = data.sort_values(by=['runtime'], ascending=False)
tmp[['original_title','runtime']]

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '768	Winnie the Pooh'

# %%
tmp = data.sort_values(by=['runtime'])
tmp[['original_title','runtime']]

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers[4] = '110'

# %%
tmp = data.sort_values(by=['runtime'])
tmp['runtime'].mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers[5] = '107.0'

# %%
tmp = data.sort_values(by=['runtime'])
tmp['runtime'].median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
answers[6] = '239	Avatar'

# %%
data['profit'] = data['revenue'] - data['budget']
tmp = data.sort_values(by=['profit'], ascending=False)
tmp[['original_title','profit']]

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
data['profit'] = data['revenue'] - data['budget']
tmp = data.sort_values(by=['profit'])
tmp[['original_title','profit']]

# %%
answers[7] = '1245	The Lone Ranger'

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
tmp[tmp.profit > 0]['original_title'].count()
# Out:
# 1478

# %%
answers[8] = '1478'

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
tmp2 = tmp[tmp['release_year'] == 2008].sort_values(by='revenue', ascending=False)
tmp2[['original_title', 'revenue']]

# %%
answers[9] = '599	The Dark Knight'

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
lst = ['Winter\'s Tale', 'Stolen', 'Broken City', 'Upside Down', 'The Lone Ranger']
tmp = data[(data['release_year'] >= 2012) & (data['release_year'] <= 2014) & (data['original_title'].isin(lst))].sort_values(by=['profit'])
tmp[['original_title', 'profit']]

# %%
answers[10] = '1245	The Lone Ranger'

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv')
data['genres'] = data['genres'].apply(lambda x: x.split('|'))
datagenre = data.explode('genres')
datagenre.genres.value_counts().sort_values(ascending=False)
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genres, dtype: int64

# %%
answers[11] = 'Drama'

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv')
data['profit'] = data['revenue'] - data['budget']
data['genres'] = data['genres'].apply(lambda x: x.split('|'))
datagenre = data.explode('genres')
datagenre[datagenre['profit'] > 0]['genres'].value_counts().sort_values(ascending=False)
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %%
answers[12] = 'Drama'

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv')
data['profit'] = data['revenue'] - data['budget']
data['director'] = data['director'].apply(lambda x: x.split('|'))
datagenre = data.explode('director')
datagenre.groupby('director')['revenue'].sum().reset_index().sort_values(by=['revenue'], ascending=False)
# Out:
#               director     revenue
# 727      Peter Jackson  6490593685
# 151  Christopher Nolan  4167548502
# 220        David Yates  4154295625
# 621        Michael Bay  3886938960
# 361        J.J. Abrams  3579169916
# ..                 ...         ...
# 208      David MichÃ´d     2295423
# 900   Steven Shainberg     2281089
# 707      Paul Schrader     2062066
# 524       Keanu Reeves     2054941
# 860       Simon Hunter     2033165
#
# [997 rows x 2 columns]

# %%
answers[13] = 'Peter Jackson'

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv')
data['genres'] = data['genres'].apply(lambda x: x.split('|'))
data['director'] = data['director'].apply(lambda x: x.split('|'))
tmp = data.explode('genres')
tmp = tmp.explode('director')
tmp[tmp.genres == 'Action'].director.value_counts().sort_values(ascending=False)
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Andy Fickman          1
# Dean DeBlois          1
# John Carpenter        1
# Wayne Kramer          1
# Tommy Wirkola         1
# Name: director, Length: 364, dtype: int64

# %%
answers[14] = 'Robert Rodriguez'

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data['cast'] = data['cast'].apply(lambda x: x.split('|'))
data['director'] = data['director'].apply(lambda x: x.split('|'))
datadirector = data.explode('director')
datacast = data.explode('cast')
datacast = datacast[datacast['release_date'].apply(lambda x: '2012' in x)]
datacast.groupby('cast')['revenue'].sum().sort_values(ascending=False)
# Out:
# Tokenization took: 8.37 ms
# Type conversion took: 11.01 ms
# Parser memory cleanup took: 0.01 ms
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %%
answers[15] = 'Chris Hemsworth'

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
bdg = data[data.budget > data.budget.mean()]
bdg['cast'] = bdg['cast'].apply(lambda x: x.split('|'))
datacast = bdg.explode('cast')
datacast.cast.value_counts(ascending=False)
# Out:
# Tokenization took: 8.05 ms
# Type conversion took: 11.58 ms
# Parser memory cleanup took: 0.01 ms
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Tom Cruise           15
# Eddie Murphy         15
#                      ..
# Leonard Nimoy         1
# Orlando Jones         1
# Judy Greer            1
# Alexander Gould       1
# Haley Joel Osment     1
# Name: cast, Length: 1505, dtype: int64

# %%
answers[16] = 'Matt Damon'

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['cast'] = data['cast'].apply(lambda x: x.split('|'))
data['genres'] = data['genres'].apply(lambda x: x.split('|'))
datagenre = data.explode('genres')
datacast = datagenre.explode('cast')
genres = datacast.query('cast == "Nicolas Cage"')
genres.genres.value_counts().sort_values(ascending=False)
# Out:
# Tokenization took: 8.44 ms
# Type conversion took: 12.02 ms
# Parser memory cleanup took: 0.01 ms
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Family              3
# Animation           3
# Mystery             3
# History             2
# War                 1
# Horror              1
# Romance             1
# Name: genres, dtype: int64

# %%
answers[17] = 'Action'

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data['production_companies'] = data['production_companies'].apply(lambda x: x.split('|'))
tmp = data.explode('production_companies')
tmp2 = tmp.query('production_companies == "Paramount Pictures"')
tmp2.sort_values(by='profit', ascending=True)[['original_title', 'profit']]
# Out:
# Tokenization took: 8.09 ms
# Type conversion took: 11.72 ms
# Parser memory cleanup took: 0.01 ms
#                                          original_title     profit
# 925                                K-19: The Widowmaker  -64831034
# 1123                                           Timeline  -60519261
# 1722                                               Next  -51788987
# 1623                                              Alfie  -46604061
# 1631                                            Twisted  -24805000
# ...                                                 ...        ...
# 730                Mission: Impossible - Ghost Protocol  549713380
# 1738                                       Transformers  559709780
# 603   Indiana Jones and the Kingdom of the Crystal S...  601636033
# 317                 Transformers: Revenge of the Fallen  686297228
# 828                      Transformers: Dark of the Moon  928746996
#
# [122 rows x 2 columns]

# %%
answers[18] = 'K-19: The Widowmaker'

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data.groupby('release_year')['revenue'].sum().sort_values(ascending=False)
# Out:
# Tokenization took: 12.48 ms
# Type conversion took: 11.31 ms
# Parser memory cleanup took: 0.01 ms
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %%
answers[19] = '2015'

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data['production_companies'] = data['production_companies'].apply(lambda x: x.split('|'))
tmp = data.explode('production_companies')
tmp.query('"Warner Bros." == production_companies')
tmp.groupby('release_year')['profit'].sum().sort_values(ascending=False)
# Out:
# Tokenization took: 9.54 ms
# Type conversion took: 11.83 ms
# Parser memory cleanup took: 0.01 ms
# release_year
# 2015    65334625738
# 2014    58543466580
# 2009    48823521075
# 2011    46949975181
# 2013    45496589970
# 2010    43327868529
# 2012    42692162023
# 2007    39556812949
# 2008    38055266115
# 2004    32433267183
# 2005    29365704422
# 2003    29122447864
# 2006    28493249688
# 2002    25662346177
# 2001    24928075425
# 2000    18995157324
# Name: profit, dtype: int64

# %%
answers[20] = '2015'

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
def get_month(s):
  return s[0:s.find('/')]


data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data['mounth'] = data['release_date'].apply(lambda x: get_month(x))
data.mounth.value_counts(ascending=False)
# Out:
# Tokenization took: 11.10 ms
# Type conversion took: 11.00 ms
# Parser memory cleanup took: 0.01 ms
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: mounth, dtype: int64

# %%
answers[21] = 'сентябрь'

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
def get_month(s):
  return s[0:s.find('/')]


data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data['mounth'] = data['release_date'].apply(lambda x: get_month(x))
data.query('mounth in ["6", "7", "8"]').info()
# Out:
# Tokenization took: 5.97 ms
# Type conversion took: 11.09 ms
# Parser memory cleanup took: 0.01 ms
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 1888
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               450 non-null    object
#  1   budget                450 non-null    int64
#  2   revenue               450 non-null    int64
#  3   original_title        450 non-null    object
#  4   cast                  450 non-null    object
#  5   director              450 non-null    object
#  6   tagline               450 non-null    object
#  7   overview              450 non-null    object
#  8   runtime               450 non-null    int64
#  9   genres                450 non-null    object
#  10  production_companies  450 non-null    object
#  11  release_date          450 non-null    object
#  12  vote_average          450 non-null    float64
# ...

# %%
answers[22] = '450'

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
def get_month(s):
  return s[0:s.find('/')]


data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['profit'] = data['revenue'] - data['budget']
data['mounth'] = data['release_date'].apply(lambda x: get_month(x))
tmp = data.query('mounth in ["12", "1", "2"]')
tmp['director'] = data['director'].apply(lambda x: x.split('|'))
tmp = tmp.explode('director')
tmp.groupby(by='director')['director'].value_counts().sort_values(ascending=False)
# Out:
# Tokenization took: 9.05 ms
# Type conversion took: 9.97 ms
# Parser memory cleanup took: 0.01 ms
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# director               director
# Peter Jackson          Peter Jackson            7
# Steven Soderbergh      Steven Soderbergh        6
# Clint Eastwood         Clint Eastwood           6
# Martin Scorsese        Martin Scorsese          4
# Adam Shankman          Adam Shankman            4
#                                                ..
# Matt Bettinelli-Olpin  Matt Bettinelli-Olpin    1
# Matt Reeves            Matt Reeves              1
# Matthew O'Callaghan    Matthew O'Callaghan      1
# ...

# %%
answers[23] = 'Peter Jackson'

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['production_companies'] = data['production_companies'].apply(lambda x: x.split('|'))
tmp = data.explode('production_companies')
tmp['length'] = tmp.original_title.apply(lambda x: len(x))
tmp.groupby('production_companies')['length'].max().sort_values(ascending=False)
# Out:
# Tokenization took: 10.74 ms
# Type conversion took: 10.79 ms
# Parser memory cleanup took: 0.01 ms
# production_companies
# Four By Two Productions                   83
# Twentieth Century Fox Film Corporation    83
# Walden Media                              62
# Walt Disney                               62
# Jim Henson Company, The                   59
#                                           ..
# Everest Entertainment                      3
# Berlanti Productions                       3
# XM2 Productions                            2
# Global Entertainment Group                 2
# Ixtlan Productions                         2
# Name: length, Length: 1771, dtype: int64

# %%
answers[24] = 'Four By Two Productions'

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
data['production_companies'] = data['production_companies'].apply(lambda x: x.split('|'))
tmp = data.explode('production_companies')
tmp['length'] = tmp.overview.apply(lambda x: len(x))
tmp.groupby('production_companies')['length'].mean().sort_values(ascending=False)
# Out:
# Tokenization took: 5.67 ms
# Type conversion took: 10.86 ms
# Parser memory cleanup took: 0.01 ms
# production_companies
# Midnight Picture Show                    1000.0
# Room 9 Entertainment                      964.0
# Brookwell-McNamara Entertainment          936.0
# Lions Gate Family Entertainment           909.0
# Crest Animation Productions               909.0
#                                           ...
# Projection Pictures                        74.0
# London Boulevard                           74.0
# Phantom Four                               72.0
# Empire Pictures                            62.0
# Motion Picture Corporation of America      59.0
# Name: length, Length: 1771, dtype: float64

# %%
answers[25] = 'Midnight Picture Show'

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
ids = data.vote_average.sort_values(ascending=False).head(19).index # 19 = 1% 
data[data.index.isin(ids)].original_title.sort_values()
# Out:
# Tokenization took: 5.77 ms
# Type conversion took: 10.40 ms
# Parser memory cleanup took: 0.01 ms
# 1191                                 12 Years a Slave
# 1563            Eternal Sunshine of the Spotless Mind
# 128                                         Gone Girl
# 119                           Guardians of the Galaxy
# 370                                         Inception
# 9                                          Inside Out
# 118                                      Interstellar
# 1800                                          Memento
# 283                                        Mr. Nobody
# 34                                               Room
# 599                                   The Dark Knight
# 138                          The Grand Budapest Hotel
# 125                                The Imitation Game
# 1081    The Lord of the Rings: The Return of the King
# 863             The Lord of the Rings: The Two Towers
# 872                                       The Pianist
# ...

# %%
answers[26] = 'Inside Out, The Dark Knight, 12 Years a Slave'

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
len1 = len(data[(data.cast.str.contains('Johnny Depp')) & (data.cast.str.contains('Helena Bonham Carter'))])
len2 = len(data[(data.cast.str.contains('Ben Stiller')) & (data.cast.str.contains('Owen Wilson'))])
len3 = len(data[(data.cast.str.contains('Vin Diesel')) & (data.cast.str.contains('Paul Walker'))])
len4 = len(data[(data.cast.str.contains('Adam Sandle')) & (data.cast.str.contains('Kevin James'))])
len5 = len(data[(data.cast.str.contains('Daniel Radcliffe')) & (data.cast.str.contains('Rupert Grint'))])
print(len1, len2, len3, len4, len5)
# Out:
# Tokenization took: 8.50 ms
# Type conversion took: 10.88 ms
# Parser memory cleanup took: 0.01 ms
# 6 6 5 5 8

# %% [markdown]
# ВАРИАНТ 2

# %%
data = pd.read_csv('/content/drive/My Drive/movie_bd_v5.csv', verbose=True)
len1 = len(data[(data.cast.apply(lambda x: 'Johnny Depp' in x)) & (data.cast.apply(lambda x: 'Helena Bonham Carter' in x))])
len2 = len(data[(data.cast.apply(lambda x: 'Ben Stiller' in x)) & (data.cast.apply(lambda x: 'Owen Wilson' in x))])
len3 = len(data[(data.cast.apply(lambda x: 'Vin Diesel' in x)) & (data.cast.apply(lambda x: 'Paul Walker' in x))])
len4 = len(data[(data.cast.apply(lambda x: 'Adam Sandle' in x)) & (data.cast.apply(lambda x: 'Kevin James' in x))])
len5 = len(data[(data.cast.apply(lambda x: 'Daniel Radcliffe' in x)) & (data.cast.apply(lambda x: 'Rupert Grint' in x))])
print(len1, len2, len3, len4, len5)
# Out:
# Tokenization took: 6.70 ms
# Type conversion took: 10.04 ms
# Parser memory cleanup took: 0.01 ms
# 6 6 5 5 8

# %%
answers[27] = 'Daniel Radcliffe & Rupert Grint'

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '723   Pirates of the Caribbean: On Stranger Tides',
#  10: '1245\tThe Lone Ranger',
#  11: 'Drama',
#  12: 'Drama',
#  13: 'Peter Jackson',
#  14: 'Robert Rodriguez',
#  15: 'Chris Hemsworth',
#  16: 'Matt Damon',
#  17: 'Action',
#  18: 'K-19: The Widowmaker',
#  19: '2015',
#  '2': '1157\tGods and Generals',
#  20: '2015',
#  21: 'сентябрь',
#  22: '450',
#  23: 'Peter Jackson',
#  24: 'Four By Two Productions',
#  25: 'Midnight Picture Show',
#  26: 'Inside Out, The Dark Knight, 12 Years a Slave',
#  27: 'Daniel Radcliffe & Rupert Grint',
#  '3': '768\tWinnie the Pooh',
#  4: '110',
#  5: '107.0',
#  6: '239\tAvatar',
#  7: '1245\tThe Lone Ranger',
#  8: '1478',
#  9: '599\tThe Dark Knight'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
